# %% [markdown]
# # Information Model vs Data Model
#
# ![%E6%88%AA%E5%B1%8F2020-09-05%E4%B8%8A%E5%8D%8810.53.02.png](attachment:%E6%88%AA%E5%B1%8F2020-09-05%E4%B8%8A%E5%8D%8810.53.02.png)
#
# * An information model is an abstract formal representation of entities that includes their properties, relationships, and the operations that can be performed on them. The entities being modeled can be from the real world, such as a library.
# * Information models and data models are different and serve different purposes.
#    * An information model is at the conceptual level and defines relationships between objects
#    * Data models are defined in a more concrete level, are specific, and include details.
#       * A data model is a blueprint of any database system

# %% [markdown]
# ## Type of Information Model: Hierarchical
# ![%E6%88%AA%E5%B1%8F2020-09-05%E4%B8%8A%E5%8D%8810.58.24.png](attachment:%E6%88%AA%E5%B1%8F2020-09-05%E4%B8%8A%E5%8D%8810.58.24.png)
# A hierarchical model orgnizes data using a tree structure. Typically used to show organization charts.
# The root of the tree is the parent node followed by child nodes
#    * A child note cannot have more than one parent, but a parent can have many child nodes

# %% [markdown]
# ## Relational Model
# * Most used data model
# * Allows for data independence
# * Data is stored in tables
# ![%E6%88%AA%E5%B1%8F2020-09-05%E4%B8%8A%E5%8D%8811.08.33.png](attachment:%E6%88%AA%E5%B1%8F2020-09-05%E4%B8%8A%E5%8D%8811.08.33.png)

# %% [markdown]
# ## Entity-Relationship Model
# An entity-relationship model proposes thinking of a database as a coleection of entities, rather than being used as a model on its own.
# * Used as a tool to design relational databases
# * Building blocks: Entities and Attributes
#
# ### Entity-Relationship Diagram
# * Simplified library example, Books are written by Authors
# * Author entity
# ![%E6%88%AA%E5%B1%8F2020-09-05%E4%B8%8B%E5%8D%884.01.09.png](attachment:%E6%88%AA%E5%B1%8F2020-09-05%E4%B8%8B%E5%8D%884.01.09.png)
# * The entity author becomes a table
