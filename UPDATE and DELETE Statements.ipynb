# %% [markdown]
# # Altering rows of a table - UPDATE statement
# * After creating a table and inserting data into the table, we can alter the data
#    * UPDATE statement: A Data Manipulation Langeage (DML) statement used to read and modify data
#
#    ![%E6%88%AA%E5%B1%8F2020-09-04%E4%B8%8B%E5%8D%885.10.03.png](attachment:%E6%88%AA%E5%B1%8F2020-09-04%E4%B8%8B%E5%8D%885.10.03.png)

# %% [markdown]
# To alter or modify the data in the Author table, we use the UPDATE statement

# %%
UPDATE[TableName]
SET [[SolumnName]=[Value]]
<WHERE [Condition]>

# %% [markdown]
# ## Using the UPDATE Statement
# ![%E6%88%AA%E5%B1%8F2020-09-04%E4%B8%8B%E5%8D%885.13.04.png](attachment:%E6%88%AA%E5%B1%8F2020-09-04%E4%B8%8B%E5%8D%885.13.04.png)
#
#              UPDATE AUTHOR
#
#              SET     LASTNAME = KATTA
#
#                      FIRSTNAME = LAKSHMI
#
#              WHERE   AUTHOR_ID = A2
#
# ![%E6%88%AA%E5%B1%8F2020-09-04%E4%B8%8B%E5%8D%885.14.27.png](attachment:%E6%88%AA%E5%B1%8F2020-09-04%E4%B8%8B%E5%8D%885.14.27.png)

# %% [markdown]
# # Deleting Rows from a table
# * Remove 1 or more rows from the table:
#   * DELETE statement
#      *
