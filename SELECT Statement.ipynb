# %% [markdown]
# ## Retrieving rows from a table
# * After creating a table and inserting data into the table, we want to see the data
# * SELECT statement
#     * A Data Manipulation Language (DML) statement used to read and modify data
#
#          Select statement:      Query
#
#          Result from the query: Result set/table

# %% [raw]
# select*from<tablename>

# %% [markdown]
# ## Example: Using the SELECT Statement
# Example: select*from Book
#
# Based on the book entity example, we would create the table using the entity name book and the entity attributes as the columns of the table. The data would be added to the book table by adding rows to the table using the insert statement.
#
# ![%E6%88%AA%E5%B1%8F2020-09-04%E4%B8%8B%E5%8D%883.50.16.png](attachment:%E6%88%AA%E5%B1%8F2020-09-04%E4%B8%8B%E5%8D%883.50.16.png)
#
# In addition, you can also retrieve all the rows for all columns by specifyting the column names individually in the SELECT statement.
#
# ![%E6%88%AA%E5%B1%8F2020-09-04%E4%B8%8B%E5%8D%884.10.24.png](attachment:%E6%88%AA%E5%B1%8F2020-09-04%E4%B8%8B%E5%8D%884.10.24.png)

# %% [markdown]
# ### Retrieving a subset of the columns
# * You can retrieve just the columns you want
# * The order of the columns displayed always matches the order in the select statement
#
# ![%E6%88%AA%E5%B1%8F2020-09-04%E4%B8%8B%E5%8D%884.10.53.png](attachment:%E6%88%AA%E5%B1%8F2020-09-04%E4%B8%8B%E5%8D%884.10.53.png)

# %% [markdown]
# ### Restricting the Result Set: WHERE Clause
# * Restrcits the result set
# * Always requires a Predicate:
#     * Evaluates to:
#       True, False or Unknown
#     * Used in the search condition of the Where clause
#
# ![%E6%88%AA%E5%B1%8F2020-09-04%E4%B8%8B%E5%8D%884.13.54.png](attachment:%E6%88%AA%E5%B1%8F2020-09-04%E4%B8%8B%E5%8D%884.13.54.png)
#
# ### WHERE Clause Comparison Operators
# ![%E6%88%AA%E5%B1%8F2020-09-04%E4%B8%8B%E5%8D%884.15.47.png](attachment:%E6%88%AA%E5%B1%8F2020-09-04%E4%B8%8B%E5%8D%884.15.47.png)

# %% [markdown]
# # SELECT statement examples
#
# The general syntax of SELECT statement is:

# %% [markdown]
# select COLUMN1, COLUMN2,... from TABLE1
# ;

# %% [markdown]
# To retrieve a list of all country names and their IDs from the COUNTRY table we would issue:

# %% [markdown]
# select ID, NAME from COUNTRY;

# %% [markdown]
# To retrieve all columns from the COUNTRY table we could use "*" instead of specifying individual column names:

# %% [markdown]
# select * from COUNTRY;

# %% [markdown]
# The WHERE clause can be added to your query to filter results or get specific rows of data. To retrieve data for all rows in the COUNTRY table where the ID is less than 5

# %% [markdown]
# select * from COUNTRY where ID < 5 ;

# %% [markdown]
# In case of character based columns the valuew of the predicates in the where clasue
