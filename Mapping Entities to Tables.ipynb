# %% [markdown]
# # ER Diagrams
# * Basic foundation for designing a database
# * Begin with ERD, and map the ERD to the table
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Example: Mapping an ERD to a Table
# * Example: Entity Book
# * Entity Book has several attributes
# * Seperate the entity from the attributes
# ![image.png](attachment:image.png)
#
# * Book = Table
# * Attributes = Columns
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Table: Book
# * Attributes get translated into columns
# ![image.png](attachment:image.png)
