# %% [markdown]
# # Relational Model Concepts
# * First proposed in1970, based on mathematical model and terms
# * Building blocks:
#   * Relation
#   * Sets
# * Set:
#   * Unordered collection of distinct elements
#   * Items of same type
#   * No order and no duplicates
#
# # Relational Database
# * A set of relations
# * Relation = mathematical term for table
# * 2 parts:
#   * Relational Schema
#   * Relational Instance
#
# ## Relational Schema
# * Specifies: name of a relation, name and type of each column(attributes)
# ![image.png](attachment:image.png)
#
# ## Relational Instance
# * Relational Instance: a table made up of attributes or columns
#   * Column = attributes = field
#   * Row = tuple
#   * Degree = the number of attributes in a relation
#   * Cardinality - the nimber of tuples ( or rows)
#   ![image-2.png](attachment:image-2.png)
